# %% [markdown]
# Importar Pandas

# %%
import pandas as pd

# %% [markdown]
# Leer el dataset desde: https://data.boston.gov/dataset/6220d948-eae2-4e4b-8723-2dc8e67722a3/resource/f4495ee9-c42c-4019-82c1-d067f07e45d2/download/tmp7_f32p54.csv

# %%
df = pd.read_csv('https://data.boston.gov/dataset/6220d948-eae2-4e4b-8723-2dc8e67722a3/resource/f4495ee9-c42c-4019-82c1-d067f07e45d2/download/tmp7_f32p54.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3398: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Mostrar las primeras 10 filas

# %%
df.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0       PLTEST005           520                 NaN
# 1       PLTEST003          3114                 NaN
# 2       PLTEST002          3114                 NaN
# 3       PLTEST001          3114                 NaN
# 4       312030979          3201                 NaN
# 5       292152228          3301                 NaN
# 6       282080177          3801                 NaN
# 7       222000453           617                 NaN
# 8       222000599          1106                 NaN
# 9       222000592          1102                 NaN
#
#                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  SHOOTING  \
# 0           BURGLARY - RESIDENTIAL       B2            289         1
# 1             INVESTIGATE PROPERTY       B2            289         0
# 2             INVESTIGATE PROPERTY       B2            289         0
# 3             INVESTIGATE PROPERTY       B2                        0
# 4         PROPERTY - LOST/ MISSING      E13            465         0
# 5                   VERBAL DISPUTE      C11            347         0
# 6             M/V ACCIDENT - OTHER       A1                        0
# 7      LARCENY THEFT FROM BUILDING      E13                        0
# 8  FRAUD - CREDIT CARD / ATM FRAUD       B2            282         0
# 9  FRAUD - FALSE PRETENSE / SCHEME       A1             98         0
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 0  2021-10-13 00:00:00  2021     10   Wednesday     0       NaN
# 1  2021-05-12 00:00:00  2021      5   Wednesday     0       NaN
# 2  2021-05-12 00:00:00  2021      5   Wednesday     0       NaN
# 3  2021-03-29 00:00:00  2021      3      Monday     0       NaN
# 4  2021-03-22 00:00:00  2021      3      Monday     0       NaN
# 5  2021-07-28 20:45:00  2021      7   Wednesday    20       NaN
# 6  2021-11-02 13:23:00  2021     11     Tuesday    13       NaN
# 7  2021-12-30 12:30:00  2021     12    Thursday    12       NaN
# 8  2021-12-29 22:40:00  2021     12   Wednesday    22       NaN
# 9  2021-11-23 00:00:00  2021     11     Tuesday     0       NaN
#
#                                               STREET        Lat       Long  \
# 0                                      SCHROEDER PLZ  42.333679 -71.091878
# 1                                      SCHROEDER PLZ  42.333679 -71.091878
# 2                                      SCHROEDER PLZ  42.333679 -71.091878
# 3                                    SCHROEDER PLAZA   0.000000   0.000000
# 4                                      BLUE HILL AVE  42.284826 -71.091374
# 5                                            LYON ST  42.306383 -71.060212
# 6  CAMBRIDGE ST & BOWDOIN ST\nBOSTON  MA 02114\nU...  42.361190 -71.062880
# 7                                      MONTEBELLO RD  42.311768 -71.099716
# 8                                      WASHINGTON ST  42.328663 -71.085634
# 9                                            MILK ST  42.356733 -71.057559
#
#                                    Location
# 0   (42.33367921810846, -71.09187754618458)
# 1   (42.33367921810846, -71.09187754618458)
# 2   (42.33367921810846, -71.09187754618458)
# 3                                    (0, 0)
# 4   (42.28482576580488, -71.09137368938802)
# 5   (42.30638322801941, -71.06021217719662)
# 6  (42.361189964341946, -71.06287997127626)
# 7   (42.31176765436927, -71.09971563708591)
# 8   (42.32866283555608, -71.08563401183545)
# 9  (42.356733021573184, -71.05755938440176)

# %% [markdown]
# Mostrar las columnas del dataframe

# %%
df.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %% [markdown]
# ¿Cuántas filas tiene el dataset?

# %%
df.shape[0]
# Out:
# 71721

# %% [markdown]
# ¿Cuál es el código de ofensa más realizada?

# %%
col = df.OFFENSE_CODE
col.value_counts(sort=True)[:1] # codigo , apariciones
# Out:
# 3115    6841
# Name: OFFENSE_CODE, dtype: int64

# %% [markdown]
# ¿Cuál es el código de ofensa más realizada los días miércoles?

# %%
col = df[df.DAY_OF_WEEK == 'Wednesday'].OFFENSE_CODE
col.value_counts(sort=True)[:1]
# Out:
# 3115    1029
# Name: OFFENSE_CODE, dtype: int64

# %% [markdown]
# Ordenar el dataframe por el campo Street y mostrar las 10 primeras entradas

# %%
df.sort_values(by='STREET')
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 2651        212092024          3115                 NaN
# 47829       212031320           540                 NaN
# 43232       212037399          3114                 NaN
# 14772       212075340           423                 NaN
# 5496        212087601           616                 NaN
# ...               ...           ...                 ...
# 50164       212028173          3807                 NaN
# 50185       212028147          3831                 NaN
# 50198       212028130          3006                 NaN
# 50201       212028127          3802                 NaN
# 71295       210209890          3115                 NaN
#
#                          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 2651                      INVESTIGATE PERSON       A1
# 47829                  BURGLARY - COMMERICAL       A1
# 43232                   INVESTIGATE PROPERTY       A1
# 14772                   ASSAULT - AGGRAVATED       A1
# 5496                LARCENY THEFT OF BICYCLE       A1
# ...                                      ...      ...            ...
# 50164      M/V ACCIDENT - OTHER CITY VEHICLE       B3
# 50185  M/V - LEAVING SCENE - PROPERTY DAMAGE       B2
# 50198          SICK/INJURED/MEDICAL - PERSON       A1            111
# 50201         M/V ACCIDENT - PROPERTY DAMAGE       B2            320
# 71295                     INVESTIGATE PERSON       A1            162
#
#        SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 2651          0  2021-12-16 14:07:00  2021     12    Thursday    14       NaN
# 47829         0  2021-05-13 15:14:00  2021      5    Thursday    15       NaN
# 43232         0  2021-06-05 10:28:00  2021      6    Saturday    10       NaN
# 14772         0  2021-10-17 00:23:00  2021     10      Sunday     0       NaN
# 5496          0  2021-11-30 15:15:00  2021     11     Tuesday    15       NaN
# ...         ...                  ...   ...    ...         ...   ...       ...
# 50164         0  2021-05-01 11:05:00  2021      5    Saturday    11       NaN
# 50185         0  2021-05-01 08:24:00  2021      5    Saturday     8       NaN
# 50198         0  2021-05-01 03:00:00  2021      5    Saturday     3       NaN
# 50201         0  2021-05-01 02:33:00  2021      5    Saturday     2       NaN
# 71295         0  2021-05-14 10:00:00  2021      5      Friday    10       NaN
#
#                 STREET        Lat       Long  \
# 2651   1 FINANCIAL CTR   0.000000   0.000000
# 47829  1 FINANCIAL CTR   0.000000   0.000000
# 43232  1 FINANCIAL CTR   0.000000   0.000000
# 14772  1 FINANCIAL CTR   0.000000   0.000000
# 5496   1 FINANCIAL CTR   0.000000   0.000000
# ...                ...        ...        ...
# 50164              NaN  42.291741 -71.077179
# 50185              NaN  42.327987 -71.099354
# 50198              NaN  42.352370 -71.062600
# 50201              NaN  42.308468 -71.083277
# 71295              NaN  42.347321 -71.064412
#
#                                        Location
# 2651                                     (0, 0)
# 47829                                    (0, 0)
# 43232                                    (0, 0)
# 14772                                    (0, 0)
# 5496                                     (0, 0)
# ...                                         ...
# 50164   (42.29174103255666, -71.07717899069988)
# 50185   (42.32798700396488, -71.09935402988641)
# 50198  (42.352370011853225, -71.06259996388145)
# 50201   (42.30846803058291, -71.08327694723572)
# 71295   (42.34732103019411, -71.06441203938374)
#
# [71721 rows x 17 columns]

# %% [markdown]
# Pasar a minúsculas todos las descripciones de ofensas

# %%
df.OFFENSE_DESCRIPTION = df.OFFENSE_DESCRIPTION.str.lower()
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           PLTEST005           520                 NaN
# 1           PLTEST003          3114                 NaN
# 2           PLTEST002          3114                 NaN
# 3           PLTEST001          3114                 NaN
# 4           312030979          3201                 NaN
# ...               ...           ...                 ...
# 71716       121005808          1102                 NaN
# 71717       121000816          3304                 NaN
# 71718       120221042          3006                 NaN
# 71719        10637224          3125                 NaN
# 71720        23844463          3115                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0                                 burglary - residential       B2
# 1                                   investigate property       B2
# 2                                   investigate property       B2
# 3                                   investigate property       B2
# 4                               property - lost/ missing      E13
# ...                                                  ...      ...
# 71716                    fraud - false pretense / scheme       B3
# 71717                        noisy party/radio-no arrest       E5
# 71718                      sick/injured/medical - person       E5
# 71719  warrant arrest - boston warrant (must be suppl...       D4
# 71720                                 investigate person       C6
#
#       REPORTING_AREA  SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  \
# 0                289         1  2021-10-13 00:00:00  2021     10   Wednesday
# 1                289         0  2021-05-12 00:00:00  2021      5   Wednesday
# 2                289         0  2021-05-12 00:00:00  2021      5   Wednesday
# 3                            0  2021-03-29 00:00:00  2021      3      Monday
# 4                465         0  2021-03-22 00:00:00  2021      3      Monday
# ...              ...       ...                  ...   ...    ...         ...
# 71716            289         0  2021-01-19 12:00:00  2021      1     Tuesday
# 71717            675         0  2021-01-04 00:00:00  2021      1      Monday
# 71718            680         0  2021-04-02 10:45:00  2021      4      Friday
# 71719            270         0  2021-01-26 18:54:00  2021      1     Tuesday
# 71720                        0  2021-10-16 01:16:00  2021     10    Saturday
#
#        HOUR  UCR_PART                                            STREET  \
# 0         0       NaN                                     SCHROEDER PLZ
# 1         0       NaN                                     SCHROEDER PLZ
# 2         0       NaN                                     SCHROEDER PLZ
# 3         0       NaN                                   SCHROEDER PLAZA
# 4         0       NaN                                     BLUE HILL AVE
# ...     ...       ...                                               ...
# 71716    12       NaN                                      CLARKWOOD ST
# 71717     0       NaN                                  BRADFIELD AVENUE
# 71718    10       NaN                                     WASHINGTON ST
# 71719    18       NaN                                    NORTHAMPTON ST
# 71720     1       NaN  G ST & E 8TH ST\nBOSTON  MA 02127\nUNITED STATES
#
#              Lat       Long                                  Location
# 0      42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 1      42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 2      42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 3       0.000000   0.000000                                    (0, 0)
# 4      42.284826 -71.091374   (42.28482576580488, -71.09137368938802)
# ...          ...        ...                                       ...
# 71716  42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 71717   0.000000   0.000000                                    (0, 0)
# 71718  42.283902 -71.130863  (42.283902436483125, -71.13086262643496)
# 71719  42.333951 -71.075389  (42.333951248393774, -71.07538938822692)
# 71720  42.331320 -71.044080   (42.33132003900925, -71.04407996166562)
#
# [71721 rows x 17 columns]

# %% [markdown]
# ¿Cuál es la distribución en deciles de la Latitud de los crímenes?

# %%
# Out:
# <bound method DataFrame.info of       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           PLTEST005           520                 NaN
# 1           PLTEST003          3114                 NaN
# 2           PLTEST002          3114                 NaN
# 3           PLTEST001          3114                 NaN
# 4           312030979          3201                 NaN
# ...               ...           ...                 ...
# 71716       121005808          1102                 NaN
# 71717       121000816          3304                 NaN
# 71718       120221042          3006                 NaN
# 71719        10637224          3125                 NaN
# 71720        23844463          3115                 NaN
#
#                                      OFFENSE_DESCRIPTION DISTRICT  \
# 0                                 burglary - residential       B2
# 1                                   investigate property       B2
# 2                                   investigate property       B2
# 3                                   investigate property       B2
# 4                               property - lost/ missing      E13
# ...                                                  ...      ...
# 71716                    fraud - false pretense / scheme       B3
# 71717                        noisy party/radio-no arrest       E5
# 71718                      sick/injured/medical - person       E5
# 71719  warrant arrest - boston warrant (must be suppl...       D4
# 71720                                 investigate person       C6
#
#       REPORTING_AREA  SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  \
# 0                289         1  2021-10-13 00:00:00  2021     10   Wednesday
# 1                289         0  2021-05-12 00:00:00  2021      5   Wednesday
# 2                289         0  2021-05-12 00:00:00  2021      5   Wednesday
# 3                            0  2021-03-29 00:00:00  2021      3      Monday
# 4                465         0  2021-03-22 00:00:00  2021      3      Monday
# ...              ...       ...                  ...   ...    ...         ...
# 71716            289         0  2021-01-19 12:00:00  2021      1     Tuesday
# 71717            675         0  2021-01-04 00:00:00  2021      1      Monday
# 71718            680         0  2021-04-02 10:45:00  2021      4      Friday
# 71719            270         0  2021-01-26 18:54:00  2021      1     Tuesday
# 71720                        0  2021-10-16 01:16:00  2021     10    Saturday
#
#        HOUR  UCR_PART                                            STREET  \
# 0         0       NaN                                     SCHROEDER PLZ
# 1         0       NaN                                     SCHROEDER PLZ
# 2         0       NaN                                     SCHROEDER PLZ
# 3         0       NaN                                   SCHROEDER PLAZA
# 4         0       NaN                                     BLUE HILL AVE
# ...     ...       ...                                               ...
# 71716    12       NaN                                      CLARKWOOD ST
# 71717     0       NaN                                  BRADFIELD AVENUE
# 71718    10       NaN                                     WASHINGTON ST
# 71719    18       NaN                                    NORTHAMPTON ST
# 71720     1       NaN  G ST & E 8TH ST\nBOSTON  MA 02127\nUNITED STATES
#
#              Lat       Long                                  Location
# 0      42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 1      42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 2      42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 3       0.000000   0.000000                                    (0, 0)
# 4      42.284826 -71.091374   (42.28482576580488, -71.09137368938802)
# ...          ...        ...                                       ...
# 71716  42.333679 -71.091878   (42.33367921810846, -71.09187754618458)
# 71717   0.000000   0.000000                                    (0, 0)
# 71718  42.283902 -71.130863  (42.283902436483125, -71.13086262643496)
# 71719  42.333951 -71.075389  (42.333951248393774, -71.07538938822692)
# 71720  42.331320 -71.044080   (42.33132003900925, -71.04407996166562)
#
# [71721 rows x 17 columns]>

# %% [markdown]
# Crear una nueva columna con la longitud de la calle donde sucedió el crimen

# %% [markdown]
# ¿Cuál es la suma de las longitudes calculadas?

# %% [markdown]
# ¿Y la mediana?

# %% [markdown]
# ¿Cuál es el promedio de esas mismas longitudes pero agrupando los datos en cada día de la semana?
